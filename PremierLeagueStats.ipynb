# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the CV file
df = pd.read_csv("C:\\Users\\User\\Desktop\\honours\\Learning from data\\EPL Standings 2000-2022.csv")
df
# Out:
#       Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts  \
# 0    2000-01    1  Manchester United   38  24   8   6  79  31  48   80
# 1    2000-01    2            Arsenal   38  20  10   8  63  38  25   70
# 2    2000-01    3          Liverpool   38  20   9   9  71  39  32   69
# 3    2000-01    4       Leeds United   38  20   8  10  64  43  21   68
# 4    2000-01    5       Ipswich Town   38  20   6  12  57  42  15   66
# ..       ...  ...                ...  ...  ..  ..  ..  ..  ..  ..  ...
# 435  2021-22   16            Everton   38  11   6  21  43  66 -23   39
# 436  2021-22   17       Leeds United   38   9  11  18  42  79 -37   38
# 437  2021-22   18            Burnley   38   7  14  17  34  53 -19   35
# 438  2021-22   19            Watford   38   6   5  27  34  77 -43   23
# 439  2021-22   20       Norwich City   38   5   7  26  23  84 -61   22
#
#                            Qualification or relegation
# 0    Qualification for the Champions League first g...
# ...

# %%
#finding unique values 
df.nunique()
# Out:
# Season                          22
# Pos                             20
# Team                            44
# Pld                              1
# W                               30
# D                               16
# L                               29
# GF                              72
# GA                              64
# GD                             112
# Pts                             80
# Qualification or relegation     37
# dtype: int64

# %%
#Whole table mean for Pts
mean_value_pts_all= df["Pts"].mean()
#Average(Mean) Points for all seasons
print("Average Points from 2000-2022:", mean_value_pts_all)
# Out:
# Average Points from 2000-2022: 52.24090909090909

# %%
#Whole table mean for Wins
mean_value= df["W"].mean()
#Average(Mean) Wins for all seasons - Same as losses
print("Average Wins from 2000-2022: ", mean_value)
# Out:
# Average Wins from 2000-2022:  14.261363636363637

# %%
#WHole table mean for losses
mean_value= df["D"].mean()
#Average(Mean) Losses for all seasons
print("Average losses from 2000-2022: ", mean_value)
# Out:
# Average losses from 2000-2022:  9.477272727272727

# %%
#Mean for wins in 2005-2006 season 
season_2005_2006 = df[df['Season'] == '2005-06']

total_wins = season_2005_2006['W'].sum()
#returning the number of rows in the season_2005_2006.
total_teams = season_2005_2006.shape[0]
mean_wins = total_wins / total_teams

print("Mean number of wins for the 2005-2006 season:", mean_wins)
# Out:
# Mean number of wins for the 2005-2006 season: 15.15

# %%
#Mean for wins in 2010-2011
season_2010_2011 = df[df['Season'] == '2010-11']

total_wins = season_2010_2011['W'].sum()
#returning the number of rows in the season_2010_2011.
total_teams = season_2010_2011.shape[0] 
mean_wins = total_wins / total_teams

print("Mean number of wins for the 2010-2011 season:", mean_wins)
# Out:
# Mean number of wins for the 2010-2011 season: 13.45

# %%
#Mean for wins in 2015-2016 season
season_2015_2016 = df[df['Season'] == '2015-16']

total_wins = season_2015_2016['W'].sum()
#returning the number of rows in the season_2015_2016.
total_teams = season_2015_2016.shape[0]
mean_wins = total_wins / total_teams

print("Mean number of wins for the 2015-2016 season:", mean_wins)
# Out:
# Mean number of wins for the 2015-2016 season: 13.65

# %%
#Mean for wins in 2020-2021
season_2020_2021 = df[df['Season'] == '2020-21']

total_wins = season_2020_2021['W'].sum()
#returning the number of rows in the season_2020_2021.
total_teams = season_2020_2021.shape[0]
mean_wins = total_wins / total_teams

print("Mean number of wins for the 2020-2021 season:", mean_wins)
# Out:
# Mean number of wins for the 2020-2021 season: 14.85

# %%
#Comparing wins from 2005-06 and 2021-21 
season_2005_2006 = df[df['Season'] == '2005-06']
total_wins_2005_2006 = season_2005_2006['W'].sum()

# Calculating the total number of teams for the 2005-2006 season
total_teams_2005_2006 = season_2005_2006.shape[0]
# Calculating the mean number of wins for the 2005-2006 season
mean_wins_2005_2006 = total_wins_2005_2006 / total_teams_2005_2006
print("Mean number of wins for the 2005-2006 season:", mean_wins_2005_2006)

season_2020_2021 = df[df['Season'] == '2020-21']
# Calculating the total number of wins for the 2020-2021 season
total_wins_2020_2021 = season_2020_2021['W'].sum()
# Calculating the total number of teams for the 2020-2021 season
total_teams_2020_2021 = season_2020_2021.shape[0]

# Calculating the mean number of wins for the 2020-2021 season
mean_wins_2020_2021 = total_wins_2020_2021 / total_teams_2020_2021
print("Mean number of wins for the 2020-2021 season:", mean_wins_2020_2021)

# Calculating the difference in mean number of wins between the two seasons
mean_difference = mean_wins_2020_2021 - mean_wins_2005_2006
print("Mean difference between the 2005-2006 season and the 2020-2021 season:", mean_difference)
# Check if the mean difference is negative and print the corresponding message
if mean_difference < 0:
    print("It indicates that in the 2005 season, teams had won more games than the recent season.")
# Out:
# Mean number of wins for the 2005-2006 season: 15.15
# Mean number of wins for the 2020-2021 season: 14.85
# Mean difference between the 2005-2006 season and the 2020-2021 season: -0.3000000000000007
# It indicates that in the 2005 season, teams had won more games than the recent season.

# %%
#Comparing Pts from 2005-06 and 2021-21 
season_2005_2006 = df[df['Season'] == '2005-06']

total_points_2005_2006 = season_2005_2006['Pts'].sum()

total_teams_2005_2006 = season_2005_2006.shape[0]

mean_points_2005_2006 = total_points_2005_2006 / total_teams_2005_2006

print("Mean number of points for the 2005-2006 season:", mean_points_2005_2006)

season_2020_2021 = df[df['Season'] == '2020-21']

total_points_2020_2021 = season_2020_2021['Pts'].sum()

total_teams_2020_2021 = season_2020_2021.shape[0]

mean_points_2020_2021 = total_points_2020_2021 / total_teams_2020_2021

print("Mean number of points for the 2020-2021 season:", mean_points_2020_2021)

mean_difference_points = mean_points_2020_2021 - mean_points_2005_2006

print("Mean difference between the 2005-2006 season and the 2020-2021 season:", mean_difference_points)

if mean_difference_points < 0:
    print("It indicates that the 2005 season, teams scored more points.")
# Out:
# Mean number of points for the 2005-2006 season: 53.15
# Mean number of points for the 2020-2021 season: 52.85
# Mean difference between the 2005-2006 season and the 2020-2021 season: -0.29999999999999716
# It indicates that the 2005 season, teams scored more points.

# %%
#Identify year , team, season for max Wins, Draws and losses

#retrieves the corresponding values
max_wins_index = df['W'].idxmax()
max_wins_year = df.loc[max_wins_index, 'Season']
max_wins_team = df.loc[max_wins_index, 'Team']
max_wins_count = df.loc[max_wins_index, 'W']
max_wins_points = df.loc[max_wins_index, 'Pts']

#Prints those corresponding values 
print("Year, team, number of wins, and points with the maximum number of wins:")
print("Year:", max_wins_year)
print("Team:", max_wins_team)
print("Number of wins:", max_wins_count)
print("Points:", max_wins_points)

#FInds the max for the following 
max_draws_index = df['D'].idxmax()
max_draws_year = df.loc[max_draws_index, 'Season']
max_draws_team = df.loc[max_draws_index, 'Team']
max_draws_count = df.loc[max_draws_index, 'D']
max_draws_points = df.loc[max_draws_index, 'Pts']

print("\nYear, team, number of draws, and points with the maximum number of draws:")
print("Year:", max_draws_year)
print("Team:", max_draws_team)
print("Number of draws:", max_draws_count)
print("Points:", max_draws_points)

max_losses_index = df['L'].idxmax()
max_losses_year = df.loc[max_losses_index, 'Season']
max_losses_team = df.loc[max_losses_index, 'Team']
max_losses_count = df.loc[max_losses_index, 'L']
max_losses_points = df.loc[max_losses_index, 'Pts']

print("\nYear, team, number of losses, and points with the maximum number of losses:")
print("Year:", max_losses_year)
print("Team:", max_losses_team)
print("Number of losses:", max_losses_count)
print("Points:", max_losses_points)
# Out:
# Year, team, number of wins, and points with the maximum number of wins:
# Year: 2017-18
# Team: Manchester City
# Number of wins: 32
# Points: 100
#
# Year, team, number of draws, and points with the maximum number of draws:
# Year: 2003-04
# Team: Newcastle United
# Number of draws: 17
# Points: 56
#
# Year, team, number of losses, and points with the maximum number of losses:
# Year: 2005-06
# Team: Sunderland
# Number of losses: 29
# Points: 15

# %%
# Calculate percentiles for points
percentiles = np.percentile(df["Pts"], [25, 50, 75])
print("25th Percentile (Q1): ", percentiles[0])
print("50th Percentile (Median): ", percentiles[1])
print("75th Percentile (Q3): ", percentiles[2])
# Out:
# 25th Percentile (Q1):  40.75
# 50th Percentile (Median):  48.0
# 75th Percentile (Q3):  63.25

# %%
#QUARTILES Q1
Q1= df["Pts"].quantile(0.25)
print("Q1:", Q1)
# Out:
# Q1: 40.75

# %%
#QUARTILES Q2
Q2 = df["Pts"].quantile(0.50)
print("Q2 Median:", Q2)
# Out:
# Q2 Median: 48.0

# %%
#Q3 QUARTILES Q3
Q3 =  df["Pts"].quantile(0.75)
print("Q3:", Q3)
# Out:
# Q3: 63.25

# %%
#Geometric mean for Pts (ENtire dataset)

from scipy.stats import gmean
geometric_mean = gmean(df['Pts'])
print("Geometric mean of 'Pts' column:", geometric_mean)
# Out:
# Geometric mean of 'Pts' column: 49.45426956991632

# %%
#standard deviation of the Pts Column
standard_deviation = np.std(df['Pts'])
print("Standard Deviation for :", standard_deviation)
# Out:
# Standard Deviation for : 17.077794170179256

# %%
# Set the display format to integers
pd.options.display.float_format = '{:,.0f}'.format
summary = df['Pts'].describe()
print(summary)
# Out:
# count   440
# mean     52
# std      17
# min      11
# 25%      41
# 50%      48
# 75%      63
# max     100
# Name: Pts, dtype: float64

# %%
#Range, highest points vs lowest points (2000-2022)
max_value = df['Pts'].max()
min_value = df['Pts'].min()
pts_range = max_value - min_value

print('Maximum Points:', max_value)
print('Minimum Points:', min_value)
print('Range:', pts_range)
# Out:
# Maximum Points: 100
# Minimum Points: 11
# Range: 89

# %%
#Interquartile range of points
IQR = Q3-Q1
print('IQR : ', IQR)
# Out:
# IQR :  22.5

# %%
#Sample variance of points
points_variance = df["Pts"].var()
variance_whole = int(points_variance)
print("Sample variance: ", variance_whole)
# Out:
# Sample variance:  292

# %%
#Coefficient variance of points
co_variance = (standard_deviation/mean_value_pts_all)*100
print("Coefficient variance: ", co_variance)
# Out:
# Coefficient variance:  32.69046130200501

# %%
#Box and whisker plot for points
fig= plt.figure(figsize = (8, 5))
#Plot based on points
plt.boxplot(df['Pts'])

plt.xlabel('Points')
plt.ylabel('Value')
plt.title('Box and Whisker for points 2000-2022')

plt.show()

# %%
season_0506 = df[df['Season'] == '2005-06']

# Create a box and whisker plot for the points of the 2005-2006 season
plt.figure(figsize=(8, 5))
plt.boxplot(season_0506['Pts'])

plt.xlabel('Points')
plt.ylabel('Value')
plt.title('Box and Whisker for points - 2005-2006 season')

plt.show()

# %%
season_0506 = df[df['Season'] == '2010-11']

# Create a box and whisker plot for the points of the 2005-2006 season
plt.figure(figsize=(8, 5))
plt.boxplot(season_0506['Pts'])

plt.xlabel('Points')
plt.ylabel('Value')
plt.title('Box and Whisker for points - 2010-2011 season')

plt.show()

# %%
season_0506 = df[df['Season'] == '2015-16']

# Create a box and whisker plot for the points of the 2005-2006 season
plt.figure(figsize=(8, 5))
plt.boxplot(season_0506['Pts'])

plt.xlabel('Points')
plt.ylabel('Value')
plt.title('Box and Whisker for points - 2015-2016 season')

plt.show()

# %%
season_0506 = df[df['Season'] == '2020-21']

# Create a box and whisker plot for the points of the 2005-2006 season
plt.figure(figsize=(8, 5))
plt.boxplot(season_0506['Pts'])

plt.xlabel('Points')
plt.ylabel('Value')
plt.title('Box and Whisker for points - 2020-2021 season')

plt.show()

# %%
# Find the row(s) where the number of losses is 0 - Invincible team, THE ONLY INVINCIBLE PREMIER LEAGUE TEAM EVER 
teams_with_zero_losses = df[df['L'] == 0]
print(teams_with_zero_losses[['Season', 'Team']])
# Out:
#      Season     Team
# 60  2003-04  Arsenal

# %%
#Count how many times the "Big 6" were actually in the top 6 from 2000-2022
teams_to_count = ['Manchester United', 'Liverpool', 'Arsenal', 'Tottenham Hotspur', 'Manchester City', 'Chelsea']
team_counts = {}

for team in teams_to_count:
    #Count how many times the BIG 6 teams in the array, are in the top 6 and count
    team_df = df[(df['Team'] == team) & (df['Pos'] <= 6)]
    count = len(team_df)
    team_counts[team] = count

for team, count in team_counts.items():
    print(f"{team}: {count} times in the top 6 position")
# Out:
# Manchester United: 21 times in the top 6 position
# Liverpool: 18 times in the top 6 position
# Arsenal: 20 times in the top 6 position
# Tottenham Hotspur: 14 times in the top 6 position
# Manchester City: 13 times in the top 6 position
# Chelsea: 21 times in the top 6 position

# %%
#How many premier league titles have the "Big 6" won from 2000-2022
big_six_teams = ['Manchester United', 'Liverpool', 'Arsenal', 'Tottenham Hotspur', 'Manchester City', 'Chelsea']

team_wins_count = {}

for team in big_six_teams:
     #Count how many times the BIG 6 teams in the array, are in the first position and count
    team_wins = df[(df['Team'] == team) & (df['Pos'] == 1)]
    team_win_count = len(team_wins)
    team_wins_count[team] = team_win_count

for team, count in team_wins_count.items():
    print(f"{team} won the league {count} times")
# Out:
# Manchester United won the league 7 times
# Liverpool won the league 1 times
# Arsenal won the league 2 times
# Tottenham Hotspur won the league 0 times
# Manchester City won the league 6 times
# Chelsea won the league 5 times

# %%
#Since 21 premier leagues were won by the "Big 6", let's take a look at which team outside the big 6 won the premier league
#selects the teams outside of the "big six" that finished in the first position in the league.
non_big_six_teams = df[~df['Team'].isin(big_six_teams)]
non_big_six_wins = non_big_six_teams[non_big_six_teams['Pos'] == 1]

if len(non_big_six_wins) > 0:
    print(f"The team(s) outside the Big 6 that won the Premier League: {', '.join(non_big_six_wins['Team'].unique())}")
else:
    print("No team outside the Big 6 has won the Premier League.")
# Out:
# The team(s) outside the Big 6 that won the Premier League: Leicester City

# %%
#Which teams have got relegated the most - used chatgpt to assist me (I gave it the logic and asked it to provide me with code; 
#Then adjusted it accordingly to my table
with the logic and syntax errors!!
relegated_teams = df[df['Pos'].isin([18, 19, 20])]
relegation_counts = relegated_teams.groupby('Team').size().reset_index(name='Relegation Count')
relegation_counts = relegation_counts.sort_values(by='Relegation Count', ascending=False)
top_3_relegated_teams = relegation_counts.head(3)

print("Top 3 teams with the most relegations:")
for index, row in top_3_relegated_teams.iterrows():
    print(f"{row['Team']} has been relegated {row['Relegation Count']} times.")
# Out:
# Top 3 teams with the most relegations:
# West Bromwich Albion has been relegated 5 times.
# Norwich City has been relegated 5 times.
# Hull City has been relegated 3 times.

# %%
# Group by season and sum up the points for each season
season_points = df.groupby('Season')['Pts'].sum().reset_index(name='Total Points')
season_points_sorted = season_points.sort_values(by='Total Points', ascending=False)
top_3_seasons = season_points_sorted.head(3)

print("Top 3 seasons with the most points:")
for index, row in top_3_seasons.iterrows():
    print(f"{row['Season']} had a total of {row['Total Points']} points.")
# Out:
# Top 3 seasons with the most points:
# 2018-19 had a total of 1069 points.
# 2005-06 had a total of 1063 points.
# 2013-14 had a total of 1062 points.

# %%
#Weighted mean for the entire dataset
weighted_mean_wins = (df['W'] * df['Pld']).sum() / df['Pld'].sum()

print("Weighted mean for wins:", weighted_mean_wins)
# Out:
# Weighted mean for wins: 14.261363636363637

# %%
#Histogram for points considering all years
#Had to import these again, because it was saying bin_centers is not defined.
import numpy as np
import matplotlib.pyplot as plt

# Get the points data
Histogram = df["Pts"]
# Plot histogram
counts, bins, _ = plt.hist(Histogram, bins=20, density=True, color='blue', edgecolor='grey', alpha=0.7)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

# Plot the histogram
plt.plot(bin_centers, counts, color='yellow', linewidth=2)

# Set labels
plt.xlabel("Points")
plt.ylabel("Frequency")

# Show plot
plt.show()

# %%
#Histogram of total points per Season
df['Year'] = df['Season'].str.split('-').str[0].astype(int)

# Group the data by season and calculate the total points per season
season_points = df.groupby('Year')['Pts'].sum()

# Plot the histogram with points per season
plt.bar(season_points.index, season_points.values, color='blue', alpha=0.7)

# Add a line through the points
plt.plot(season_points.index, season_points.values, color='red', linestyle='-', marker='o', markersize=5)

plt.xlabel("Season")
plt.ylabel("Total Points")
plt.title("Total Points per Season")
plt.xticks(range(2000, 2023), rotation=45)
plt.show()

# %%
#Season with most goals vs less goals, then compare the range
df['Year'] = df['Season'].str.split('-').str[0].astype(int)

# Group the data by season and calculate the total goals scored and conceded per season
season_goals = df.groupby('Year')[['GF', 'GA']].sum()

# Calculate the total goals scored per season
season_goals['TotalGoals'] = season_goals['GF'] + season_goals['GA']

# Find the season with the least and most goals scored
min_goals_season = season_goals['TotalGoals'].idxmin()
max_goals_season = season_goals['TotalGoals'].idxmax()

# Get the corresponding Data
min_goals_scored = season_goals.loc[min_goals_season, 'TotalGoals']
min_goals_conceded = season_goals.loc[min_goals_season, 'GA']
max_goals_scored = season_goals.loc[max_goals_season, 'TotalGoals']
max_goals_conceded = season_goals.loc[max_goals_season, 'GA']

# Calculate the range of goals
goals_range = max_goals_scored - min_goals_scored

# Print the results
print("Season with the least goals scored:")
print(f"Season: {min_goals_season}")
print(f"Total Goals Scored: {min_goals_scored}")
print(f"Total Goals Conceded: {min_goals_conceded}")

print("\nSeason with the most goals scored:")
print(f"Season: {max_goals_season}")
print(f"Total Goals Scored: {max_goals_scored}")
print(f"Total Goals Conceded: {max_goals_conceded}")

print("\nRange of Goals Scored: ", goals_range)
# Out:
# Season with the least goals scored:
# Season: 2006
# Total Goals Scored: 1862
# Total Goals Conceded: 931
#
# Season with the most goals scored:
# Season: 2018
# Total Goals Scored: 2144
# Total Goals Conceded: 1072
#
# Range of Goals Scored:  282

# %%
#Line graph using the total goals scored over the years

df['Year'] = df['Season'].str.split('-').str[0].astype(int)
# Group the data by season and calculate the total goals scored per season
season_goals = df.groupby('Year')[['GF']].sum()

# Plot a line graph of total goals scored over the years
plt.plot(season_goals.index, season_goals['GF'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Total Goals Scored')
plt.title('Total Goals Scored Over the Years')
plt.grid(True)
plt.xticks(range(2000, 2022), rotation=45)
plt.show()

# %%
#Range between seasons with the most draws and least draws
df['Year'] = df['Season'].str.split('-').str[0].astype(int)
season_draws = df.groupby('Year')['D'].sum()

# Find the season with the most and least draws
max_draws_season = season_draws.idxmax()
min_draws_season = season_draws.idxmin()

# Get the corresponding data
max_draws_total = season_draws.loc[max_draws_season]
min_draws_total = season_draws.loc[min_draws_season]

# Calculate the range of draws
draws_range = max_draws_total - min_draws_total

# Print the results
print("Season with the most draws:")
print(f"Season: {max_draws_season}")
print(f"Total Draws: {max_draws_total}")

print("\nSeason with the least draws:")
print(f"Season: {min_draws_season}")
print(f"Total Draws: {min_draws_total}")

print("\nRange of Draws: ", draws_range)
# Out:
# Season with the most draws:
# Season: 2010
# Total Draws: 222
#
# Season with the least draws:
# Season: 2018
# Total Draws: 142
#
# Range of Draws:  80

# %%
#Line graph of Draws over the seasons
df['Year'] = df['Season'].str.split('-').str[0].astype(int)

# Group the data by season and calculate the total draws per season
season_draws = df.groupby('Year')['D'].sum()

# Plot a line graph of total draws over the years
plt.plot(season_draws.index, season_draws.values, marker='o', linestyle='-', color='blue')
plt.xlabel('Year')
plt.ylabel('Total Draws')
plt.title('Total Draws Over the Years')
plt.grid(True)
plt.xticks(range(2000, 2023), rotation=45)

plt.show()

# %%
#Combined top 6 table
teams_to_include = ['Manchester United', 'Arsenal', 'Manchester City', 'Tottenham Hotspur', 'Liverpool', 'Chelsea']
filtered_df = df[df['Team'].isin(teams_to_include)]
grouped_df = filtered_df.groupby('Team').agg({
    'Pld': 'sum',
    'W': 'sum',
    'D': 'sum',
    'L': 'sum',
    'GF': 'sum',
    'GA': 'sum',
    'GD': 'sum',
    'Pts': 'sum'
}).reset_index()

combined_table = grouped_df.sort_values(by='Pts', ascending=False)
#This line assigns new index values to the combined_table
combined_table.index = range(1, len(combined_table) + 1)
combined_table.index.name = 'Pos'

print(combined_table[['Team', 'Pld', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts']])
# Out:
#                   Team  Pld    W    D    L    GF    GA   GD   Pts
# Pos
# 1    Manchester United  836  507  177  152  1562   782  780  1698
# 2              Chelsea  836  492  189  155  1538   757  781  1665
# 3              Arsenal  836  470  193  173  1561   876  685  1603
# 4            Liverpool  836  464  199  173  1516   808  708  1591
# 5      Manchester City  798  428  156  214  1478   846  632  1440
# 6    Tottenham Hotspur  836  393  191  252  1323  1011  312  1370

# %%
# Assuming 'combined_table' contains your combined top 6 table
# Calculate the skewness for each column
skewness = combined_table[[ 'W', 'L']].skew()

# Plot a bar graph of skewness
plt.bar(skewness.index, skewness.values, color='blue', alpha=0.7)
plt.xlabel('Columns')
plt.ylabel('Skewness')
plt.title('Skewness of Wins and Losses in Combined Top 6 Table')
plt.xticks(rotation=45)
plt.show()

# %%
#25th, 50th and 75th percentile for combined top 6
percentiles = combined_table['Pts'].quantile([0.25, 0.50, 0.75])

print("25th Percentile (Q1): ", percentiles[0.25])
print("50th Percentile (Q2 Median): ", percentiles[0.50])
print("75th Percentile (Q3): ", percentiles[0.75])
# Out:
# 25th Percentile (Q1):  1477.75
# 50th Percentile (Q2 Median):  1597.0
# 75th Percentile (Q3):  1649.5

# %%
#Box and whisker of combined top 6 
plt.figure(figsize=(8, 5))
combined_table.boxplot(column='Pts')
plt.title('Box and Whisker Plot for Pts Column - Combined top 6')
plt.ylabel('Pts')
plt.grid(False)
plt.show()

# %%
#Range of points of combined top 6 
max_pts_c= combined_table['Pts'].max()
min_pts_c= combined_table['Pts'].min()
range= max_pts_c - min_pts_c
print("Range: ", range)
# Out:
# Range:  328

# %%
#Standard deviation of Pts, combined top 6
mean_pts = combined_table['Pts'].mean()
squared_diffs = (combined_table['Pts'] - mean_pts) ** 2
mean_squared_diffs = squared_diffs.mean()

std_dev = mean_squared_diffs ** 0.5
print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 117.8776437196167

# %%
#Sample variance of points, in combined top 6 table
mean_pts = combined_table['Pts'].mean()

# Calculate the squared differences between each data point and the mean
squared_diffs = (combined_table['Pts'] - mean_pts) ** 2
sum_squared_diffs = squared_diffs.sum()

# Calculate the sample variance (divide the sum of squared differences by n - 1)
n = len(combined_table['Pts'])
sample_variance = sum_squared_diffs / (n - 1)

print("Sample Variance:", sample_variance)
# Out:
# Sample Variance: 16674.166666666668

# %%
#Coefficient of variance of the Points
mean_pts = combined_table['Pts'].mean()
cv = (std_dev / mean_pts) * 100

print("Coefficient of Variation:", cv, "%")
# Out:
# Coefficient of Variation: 7.550612387292626 %

# %%
#Man united's games played on pie chart
man_utd_data = combined_table[combined_table['Team'] == 'Manchester United'].iloc[0]

# 2. Calculate total games played, wins, losses, and draws
total_games = man_utd_data['Pld']
total_wins = man_utd_data['W']
total_losses = man_utd_data['L']
total_draws = man_utd_data['D']

# 3. Create a pie chart
labels = ['Wins', 'Losses', 'Draws']
sizes = [total_wins, total_losses, total_draws]
colors = ['green', 'red', 'blue']
explode = (0.1, 0, 0)  # explode the 1st slice (Wins)

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Manchester United: Total Games Played (2000-2022)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
#Proving that mu favourite team (Man united, is the best :)
#Liverpools games played on pie chart
man_utd_data = combined_table[combined_table['Team'] == 'Liverpool'].iloc[0]

# 2. Calculate total games played, wins, losses, and draws
total_games = man_utd_data['Pld']
total_wins = man_utd_data['W']
total_losses = man_utd_data['L']
total_draws = man_utd_data['D']

# 3. Create a pie chart
labels = ['Wins', 'Losses', 'Draws']
sizes = [total_wins, total_losses, total_draws]
colors = ['green', 'red', 'blue']
explode = (0.1, 0, 0)  # explode the 1st slice (Wins)

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Liverpool: Total Games Played (2000-2022)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
#Create table for 2021-22 season --> To measure covariance 
#I had an issue here whereby i couldn't include 'Pos', therefore i excluded it 
data = {
    'Season': ['2021-2022'] * 20,
    'Team': ['Manchester City', 'Liverpool', 'Chelsea', 'Tottenham Hotspur', 'Arsenal',
             'Manchester United', 'West Ham United', 'Leicester City', 'Brighton & Hove Albion', 
             'Wolverhampton Wanderers', 'Newcastle United', 'Crystal Palace', 'Brentford', 
             'Aston Villa', 'Southampton', 'Everton', 'Leeds United', 'Burnley', 'Watford', 'Norwich City'],
    'GD': [73, 68, 43, 29, 13, 0, 9, 3, -2, -5, -18, 4, -8, -2, -24, -23, -37, -19, -43, -61],
    'Pts': [93, 92, 74, 71, 69, 58, 56, 52, 51, 51, 49, 48, 46, 45, 40, 39, 38, 35, 23, 22]
}

df_2021_22 = pd.DataFrame(data)
print(df_2021_22)
# Out:
#        Season                     Team  GD  Pts
# 0   2021-2022          Manchester City  73   93
# 1   2021-2022                Liverpool  68   92
# 2   2021-2022                  Chelsea  43   74
# 3   2021-2022        Tottenham Hotspur  29   71
# 4   2021-2022                  Arsenal  13   69
# 5   2021-2022        Manchester United   0   58
# 6   2021-2022          West Ham United   9   56
# 7   2021-2022           Leicester City   3   52
# 8   2021-2022   Brighton & Hove Albion  -2   51
# 9   2021-2022  Wolverhampton Wanderers  -5   51
# 10  2021-2022         Newcastle United -18   49
# 11  2021-2022           Crystal Palace   4   48
# 12  2021-2022                Brentford  -8   46
# 13  2021-2022              Aston Villa  -2   45
# 14  2021-2022              Southampton -24   40
# 15  2021-2022                  Everton -23   39
# 16  2021-2022             Leeds United -37   38
# 17  2021-2022                  Burnley -19   35
# 18  2021-2022                  Watford -43   23
# ...

# %%
#Table for 2000-2001 table
data = {
    'Season': ['2000-2001'] * 20,
    'Team': ['Manchester United', 'Arsenal', 'Liverpool', 'Leeds United', 'Ipswich Town',
             'Chelsea', 'Sunderland', 'Aston Villa', 'Charlton Athletic', 'Southampton',
             'Newcastle United', 'Tottenham Hotspur', 'Leicester City', 'Middlesbrough',
             'West Ham United', 'Everton', 'Derby County', 'Manchester City', 'Coventry City', 'Bradford City'],
    'GD': [48, 25, 32, 21, 15, 23, 5, 3, -7, -8, -6, -7, -12, 0, -5, -14, -22, -24, -27, -40],
    'Pts': [80, 70, 69, 68, 66, 61, 57, 54, 52, 52, 51, 49, 48, 42, 42, 42, 42, 34, 34, 26]
}

# Create DataFrame
df_2000_01 = pd.DataFrame(data)

# Display the table
print(df_2000_01)
# Out:
#        Season               Team  GD  Pts
# 0   2000-2001  Manchester United  48   80
# 1   2000-2001            Arsenal  25   70
# 2   2000-2001          Liverpool  32   69
# 3   2000-2001       Leeds United  21   68
# 4   2000-2001       Ipswich Town  15   66
# 5   2000-2001            Chelsea  23   61
# 6   2000-2001         Sunderland   5   57
# 7   2000-2001        Aston Villa   3   54
# 8   2000-2001  Charlton Athletic  -7   52
# 9   2000-2001        Southampton  -8   52
# 10  2000-2001   Newcastle United  -6   51
# 11  2000-2001  Tottenham Hotspur  -7   49
# 12  2000-2001     Leicester City -12   48
# 13  2000-2001      Middlesbrough   0   42
# 14  2000-2001    West Ham United  -5   42
# 15  2000-2001            Everton -14   42
# 16  2000-2001       Derby County -22   42
# 17  2000-2001    Manchester City -24   34
# 18  2000-2001      Coventry City -27   34
# 19  2000-2001      Bradford City -40   26

# %%
#Goal difference between Man united (2000-01 winner) and Man City (2021-22 winner)
gd_2000_01_manchester_united = df_2000_01[df_2000_01['Team'] == 'Manchester United']['GD'].values[0]
gd_2021_22_manchester_city = df_2021_22[df_2021_22['Team'] == 'Manchester City']['GD'].values[0]

# Compare the GD for Manchester United in 2000-2001 season and Manchester City in 2021-2022 season
print("Goal Difference for Manchester United in the 2000-2001 season:", gd_2000_01_manchester_united)
print("Goal Difference for Manchester City in the 2021-2022 season:", gd_2021_22_manchester_city)
gd_difference = gd_2000_01_manchester_united - gd_2021_22_manchester_city
print("Difference in Goal Difference (Manchester United - Manchester City):", gd_difference)
#This indicates that Manchester City had a much better goal ratio than man united
# Out:
# Goal Difference for Manchester United in the 2000-2001 season: 48
# Goal Difference for Manchester City in the 2021-2022 season: 73
# Difference in Goal Difference (Manchester United - Manchester City): -25

# %%
# Sum up the points for the 2000-2001 season
total_pts_2000_01 = df_2000_01['Pts'].sum()
print("Total points for the 2000-2001 season:", total_pts_2000_01)
# Sum up the points for the 2021-2022 season
total_pts_2021_22 = df_2021_22['Pts'].sum()
print("Total points for the 2021-2022 season:", total_pts_2021_22)
# Out:
# Total points for the 2000-2001 season: 1039
# Total points for the 2021-2022 season: 1052

# %%
# Calculate the covariance between the points for the two seasons
covariance = df_2000_01['Pts'].cov(df_2021_22['Pts'])
print("Covariance between the 'Pts' for the 2000-2001 and 2021-2022 seasons:", covariance)
# Out:
# Covariance between the 'Pts' for the 2000-2001 and 2021-2022 seasons: 261.3473684210526

# %%
# Calculate the correlation coefficient between the points for the two seasons
correlation_coefficient = df_2000_01['Pts'].corr(df_2021_22['Pts'])
print("Correlation coefficient between the 'Pts' for the 2000-2001 and 2021-2022 seasons:", correlation_coefficient)
# Out:
# Correlation coefficient between the 'Pts' for the 2000-2001 and 2021-2022 seasons: 0.9669121358601892

# %%
#Scatter plot of 2001-02 season
season = df_2000_01['Season']
goal_difference = df_2000_01['GD']

plt.scatter(season, goal_difference, color="skyblue", alpha=0.6)
plt.title('Goal Difference Over the 2000-2001 Season')
plt.xlabel('Season')
plt.ylabel('Goal Difference')
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
#Scatter plot for 2021-22 season
season_2021_22 = df_2021_22['Season']
goal_difference_2021_22 = df_2021_22['GD']

plt.scatter(season_2021_22, goal_difference_2021_22, color="skyblue", alpha=0.6)
plt.title('Goal Difference Over the 2021-2022 Season')
plt.xlabel('Season')
plt.ylabel('Goal Difference')
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
print('Conclusion: Allthough excel has limited scripting capabilities and is primarily designed for spreadsheet-based data analysis, Excel was much easier to perform analysis on, due to my familiarity with excel. Excel is more simple to analyze data, however i would say that python is much better when representing the data; Excel is much better visually. The biggest difference for me was the learning gap, i had to revise my python notes and watch many youtube videos, especially on how to create diagrams. Which one would i use? I would use Python when working with big data and stats, because python is used for machine learning too, making it much easier to work with AI languages to assist. I would definitely use excel for this data set, since it is not very large and is more interactive, visually appealing and is better to show reports alongside eachother')
print('I would say my biggest gaps in python was firstly, remembering the content i learnt in first and second year. Programming is something that requires much practice, and my lack of practice put me behind in this activity; However, after watching a few youtube videos and going over my work, i found the process much easier and i prefer using Python over any other programming langauge. The second issue was my lack of statistical knowledge, which was easier with the use of libraries. Luckily, i had no missing data or data to clean, so this process was much easier.')
# Out:
# Conclusion: Allthough excel has limited scripting capabilities and is primarily designed for spreadsheet-based data analysis, Excel was much easier to perform analysis on, due to my familiarity with excel. Excel is more simple to analyze data, however i would say that python is much better when representing the data; Excel is much better visually. The biggest difference for me was the learning gap, i had to revise my python notes and watch many youtube videos, especially on how to create diagrams. Which one would i use? I would use Python when working with big data and stats, because python is used for machine learning too, making it much easier to work with AI languages to assist. I would definitely use excel for this data set, since it is not very large and is more interactive, visually appealing and is better to show reports alongside eachother
# ...

# %%
#Link for Github Jupyter Notebook 
https://github.com/ArmaanKatkodia/Jupyter-Notebook-_Stats/blob/d0cc7c6cd292c141756548120a316ba5f82c64bd/Untitled.ipynb
